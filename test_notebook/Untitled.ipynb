# %%
import pandas as pd
import numpy as np
import os, sys
import matplotlib.pyplot as plt
import seaborn as sns
sys.path.append('../')
from models.knobs import rocksdb_knobs_make_dict

# %%
PATH_internal = "internal"
PATH_external = "external"
PATH_knobs = "rocksdb_conf"
wk_len = 16

# %%
knobs = rocksdb_knobs_make_dict(PATH_knobs)
knobs = pd.DataFrame(data=knobs['data'].astype(np.float32), columns=knobs['columnlabels'])
knobs.head(4)
# Out:
#    max_background_compactions  max_background_flushes  write_buffer_size  \
# 0                         6.0                    16.0          1304576.0
# 1                         2.0                    14.0           911360.0
# 2                         8.0                     6.0          1474560.0
# 3                        12.0                     8.0           550912.0
#
#    max_write_buffer_number  min_write_buffer_number_to_merge  compaction_pri  \
# 0                      3.0                               2.0             1.0
# 1                      6.0                               2.0             0.0
# 2                      6.0                               1.0             2.0
# 3                      7.0                               1.0             3.0
#
#    compaction_style  level0_file_num_compaction_trigger  \
# 0               0.0                                 3.0
# 1               0.0                                 7.0
# ...

# %%
columns = knobs.columns

# %%
for col in columns:
    print(f"{col:40}\t{len(knobs[[col]].value_counts())}")
# Out:
# max_background_compactions              	16
# max_background_flushes                  	16
# write_buffer_size                       	1536
# max_write_buffer_number                 	7
# min_write_buffer_number_to_merge        	2
# compaction_pri                          	4
# compaction_style                        	1
# level0_file_num_compaction_trigger      	7
# level0_slowdown_writes_trigger          	17
# level0_stop_writes_trigger              	33
# compression_type                        	4
# bloom_locality                          	2
# open_files                              	4
# block_size                              	15
# cache_index_and_filter_blocks           	2
# max_bytes_for_level_base                	7
# max_bytes_for_level_multiplier          	5
# target_file_size_base                   	1537
# target_file_size_multiplier             	2
# num_levels                              	4
# memtable_bloom_size_ratio               	5
# ...

# %%
knobs.T
# Out:
#                                          0           1           2      \
# max_background_compactions                6.00        2.00        8.00
# max_background_flushes                   16.00       14.00        6.00
# write_buffer_size                   1304576.00   911360.00  1474560.00
# max_write_buffer_number                   3.00        6.00        6.00
# min_write_buffer_number_to_merge          2.00        2.00        1.00
# compaction_pri                            1.00        0.00        2.00
# compaction_style                          0.00        0.00        0.00
# level0_file_num_compaction_trigger        3.00        7.00        5.00
# level0_slowdown_writes_trigger           24.00       18.00       18.00
# level0_stop_writes_trigger               44.00       55.00       48.00
# compression_type                          0.00        0.00        3.00
# bloom_locality                            0.00        1.00        0.00
# ...

# %%
internal_dict = {}
pruned_im = pd.read_csv(os.path.join(PATH_internal, 'internal_ensemble_pruned_tmp.csv'), index_col=0)
for wk in range(wk_len):
    im = pd.read_csv(os.path.join(PATH_internal, f'internal_results_{wk}.csv'), index_col=0)
    internal_dict[wk] = im[pruned_im.columns]
internal_dict[0].head(4)
# Out:
#                                                     rocksdb.block.cache.miss COUNT  \
# index
# /home/jieun/data_generation_rocksdb/rocksdb_con...                         1296845
# /home/jieun/data_generation_rocksdb/rocksdb_con...                         1304820
# /home/jieun/data_generation_rocksdb/rocksdb_con...                         1407632
# /home/jieun/data_generation_rocksdb/rocksdb_con...                         1497592
#
#                                                     rocksdb.block.cache.hit COUNT  \
# index
# /home/jieun/data_generation_rocksdb/rocksdb_con...                        1172926
# /home/jieun/data_generation_rocksdb/rocksdb_con...                        4192080
# /home/jieun/data_generation_rocksdb/rocksdb_con...                        2195141
# /home/jieun/data_generation_rocksdb/rocksdb_con...                        7007880
#
#                                                     rocksdb.block.cache.add COUNT  \
# index
# ...

# %%
external_dict = {}
for wk in range(wk_len):
    ex = pd.read_csv(os.path.join(PATH_external, f'external_results_{wk}.csv'), index_col=0)
    external_dict[wk] = ex
external_dict[0].head(4)
# Out:
#                                                     TIME  RATE   WAF     SA
# index
# /home/jieun/data_generation_rocksdb/rocksdb_con...  21.8  4.77   8.7  72.17
# /home/jieun/data_generation_rocksdb/rocksdb_con...  25.9  4.02   8.9  55.83
# /home/jieun/data_generation_rocksdb/rocksdb_con...  52.0  2.00   7.5  34.21
# /home/jieun/data_generation_rocksdb/rocksdb_con...  53.6  1.94  10.5  56.94

# %%
# knob_im = internal_dict[0].copy()
# col = knobs.columns[0]
# knob_im = knob_im.reset_index(drop=True)
# knob_im[col] = knobs[col]
# knob_im.head(4)
# Out:
#    rocksdb.block.cache.miss COUNT  rocksdb.block.cache.hit COUNT  \
# 0                         1296845                        1172926
# 1                         1304820                        4192080
# 2                         1407632                        2195141
# 3                         1497592                        7007880
#
#    rocksdb.block.cache.add COUNT  rocksdb.block.cache.index.miss COUNT  \
# 0                        1213729                                     0
# 1                        1256074                                  1582
# 2                        1315590                                     0
# 3                        1252738                                   974
#
#    rocksdb.block.cache.index.hit COUNT  rocksdb.block.cache.index.add COUNT  \
# 0                                    0                                    0
# 1                              2701880                                 1582
# ...

# %%
df_internals = pd.concat([internal_dict[_] for _ in range(len(internal_dict))])
df_internals = df_internals.reset_index(drop=True)
knobs_ = pd.concat([knobs[col] for _ in range(len(internal_dict))])
knobs_ = knobs_.reset_index(drop=True)

# %%
knob_im = df_internals.copy()
knob_im = knob_im.reset_index(drop=True)
knob_im[col] = knobs_
knob_im
# Out:
#         rocksdb.block.cache.miss COUNT  rocksdb.block.cache.hit COUNT  \
# 0                              1296845                        1172926
# 1                              1304820                        4192080
# 2                              1407632                        2195141
# 3                              1497592                        7007880
# 4                              1257318                        2161785
# ...                                ...                            ...
# 319995                          348266                         230398
# 319996                          378199                         221466
# 319997                          458125                         294065
# 319998                          490991                         313228
# 319999                          552802                         356032
#
#         rocksdb.block.cache.add COUNT  rocksdb.block.cache.index.miss COUNT  \
# ...

# %%
corr = knob_im.corr()

# %%
corr[[col]].sort_values(by=col).dropna()[-10:] # one IM
# Out:
#                                          max_background_compactions
# rocksdb.manifest.file.sync.micros_COUNT                    0.012565
# rocksdb.manifest.file.sync.micros_P100                     0.012567
# rocksdb.write.raw.block.micros_COUNT                       0.012578
# rocksdb.table.open.io.micros_P100                          0.012878
# rocksdb.compact.write.bytes COUNT                          0.014100
# rocksdb.compact.read.bytes COUNT                           0.014349
# rocksdb.write.raw.block.micros_P95                         0.017673
# rocksdb.write.raw.block.micros_SUM                         0.018581
# rocksdb.write.raw.block.micros_P100                        0.022538
# max_background_compactions                                 1.000000

# %%
corr[[col]].sort_values(by=col).dropna()[-10:] # all IM
# Out:
#                                             max_background_compactions
# rocksdb.db.flush.micros_P100                                  0.244139
# rocksdb.table.open.io.micros_P99                              0.246159
# rocksdb.compaction.outfile.sync.micros_P99                    0.246770
# rocksdb.db.flush.micros_P99                                   0.247211
# rocksdb.table.open.io.micros_SUM                              0.249289
# rocksdb.compaction.times.micros_P50                           0.253394
# rocksdb.table.open.io.micros_P100                             0.260326
# rocksdb.sst.read.micros_P100                                  0.264440
# rocksdb.compaction.outfile.sync.micros_P95                    0.264561
# max_background_compactions                                    1.000000

# %%
corr = {}
for col in knobs.columns:
    knobs_ = pd.concat([knobs[col] for _ in range(len(internal_dict))])
    knobs_ = knobs_.reset_index(drop=True)
    knob_im = df_internals.copy()
    knob_im = knob_im.reset_index(drop=True)
    knob_im[col] = knobs_
    
    print(col)
    c = knob_im.corr()
    print(c[[col]].sort_values(by=col).dropna()[-10:])
    print('\n')
    corr[col] = c[[col]]
# Out:
# max_background_compactions
#                                             max_background_compactions
# rocksdb.db.flush.micros_P100                                  0.244139
# rocksdb.table.open.io.micros_P99                              0.246159
# rocksdb.compaction.outfile.sync.micros_P99                    0.246770
# rocksdb.db.flush.micros_P99                                   0.247211
# rocksdb.table.open.io.micros_SUM                              0.249289
# rocksdb.compaction.times.micros_P50                           0.253394
# rocksdb.table.open.io.micros_P100                             0.260326
# rocksdb.sst.read.micros_P100                                  0.264440
# rocksdb.compaction.outfile.sync.micros_P95                    0.264561
# max_background_compactions                                    1.000000
#
#
# max_background_flushes
#                                   max_background_flushes
# rocksdb.table.sync.micros_P95                   0.023306
# ...

# %%
corr.keys()
# Out:
# dict_keys(['max_background_compactions', 'max_background_flushes', 'write_buffer_size', 'max_write_buffer_number', 'min_write_buffer_number_to_merge', 'compaction_pri', 'compaction_style', 'level0_file_num_compaction_trigger', 'level0_slowdown_writes_trigger', 'level0_stop_writes_trigger', 'compression_type', 'bloom_locality', 'open_files', 'block_size', 'cache_index_and_filter_blocks', 'max_bytes_for_level_base', 'max_bytes_for_level_multiplier', 'target_file_size_base', 'target_file_size_multiplier', 'num_levels', 'memtable_bloom_size_ratio', 'compression_ratio'])

# %%
corr['max_background_compactions']
# Out:
#                                       max_background_compactions
# rocksdb.block.cache.miss COUNT                         -0.016268
# rocksdb.block.cache.hit COUNT                          -0.021503
# rocksdb.block.cache.add COUNT                          -0.029103
# rocksdb.block.cache.index.miss COUNT                   -0.012063
# rocksdb.block.cache.index.hit COUNT                    -0.014665
# ...                                                          ...
# rocksdb.db.flush.micros_P99                             0.247211
# rocksdb.db.flush.micros_P100                            0.244139
# rocksdb.db.flush.micros_COUNT                           0.002655
# rocksdb.db.flush.micros_SUM                             0.122990
# max_background_compactions                              1.000000
#
# [149 rows x 1 columns]
